# %% [markdown]
# <a href="https://colab.research.google.com/github/sagartanuku-cell/gitbasis-demo/blob/main/Masai_1_0_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Player_name =   input ("enter players name")
# Out:
# enter players namesagar

# %%
games_played =  int(input ("enter games played"))
# Out:
# enter games played20

# %%
print(type(Games_played))
# Out:
# <class 'int'>

# %%
total_score =   int(input ("enter total score"))
# Out:
# enter total score100

# %%
avg_score = total_score / Games_played
print (avg_score)
# Out:
# 5.0

# %%
print(f"player: {player_name}")

print(f"games played: {Games_played}")

print(f"Average score: {avg_score}")

print(f"Total score: {total_score}")
# Out:
# player: sagar
# games played: 20
# Average score: 5.0
# Total score: 100
